# %%
import regex_search
import pandas as pd



uvm_df = pd.read_excel('../data/uvm_ground_truth 1.xlsx')
ucla_df = pd.read_excel('../data/ucla_ground_truth 1.xlsx')
und_df = pd.read_excel('../data/und_ground_truth 1.xlsx')

uvm_df = pd.concat([uvm_df, ucla_df, und_df])

# %%
uvm_df.shape
# Out:
# (2981, 21)

# %%
uvm_df['is_ug'] = uvm_df['cat_type'] == 'ug'
uvm_df['is_gr'] = uvm_df['cat_type'] == 'gr'
uvm_df['is_both'] = uvm_df['cat_type'] == 'both'

uvm_df['full_description'] = uvm_df['Title'] + ' ' + uvm_df['Description']
uvm_df['full_description'] = uvm_df['full_description'].astype(str)
uvm_df['full_description'] = uvm_df['full_description'].apply(lambda x: x.lower())
uvm_df.head()
# Out:
#    ipeds_id cat_type  start_yr  end_yr  page_num  col_num     type  annote_id  \
# 0    231174       ug      1938    1939       129        0  courses     139218
# 1    231174       ug      1938    1939        78        0  courses     139132
# 2    231174       ug      1938    1939       103        0  courses     139209
# 3    231174       ug      1938    1939       148        0  courses     139227
# 4    231174       ug      1938    1939       126        0  courses     139241
#
#   Department Number  ... decade quinquennium DepartmentCleaned  \
# 0    Zoology    106  ...   1930         1935           zoology
# 1     Botany    109  ...   1930         1935           biology
# 2    History      1  ...   1930         1935           history
# 3   GENETICS    200  ...   1930         1935          genetics
# 4    SPANISH    101  ...   1930         1935           spanish
#
#                                        combined_text has_ai  is_not_course  \
# 0  Primate Anatomy A detailed dissection of the R...      0              0
# 1         Special Investigation Hours to be arranged      0              0
# 2  Ancient History A brief survey of the history ...      0              0
# 3  GENETICS A course of studies in the principles...      0              0
# 4  ELEMENTARY SPANISH A beginner's course includi...      0              0
#
#    is_ug  is_gr is_both                                   full_description
# 0   True  False   False  primate anatomy a detailed dissection of the r...
# 1   True  False   False         special investigation hours to be arranged
# 2   True  False   False  ancient history a brief survey of the history ...
# 3   True  False   False  genetics a course of studies in the principles...
# 4   True  False   False  elementary spanish a beginner's course includi...
#
# [5 rows x 25 columns]

# %%
queries = [
    "thinking machines",
    "turing",
    "neural networks",
    "symbolic reasoning",
    "logic theorist",
    "cognitive revolution",
    "natural language processing",
    "natural language",
    "algorithm",
    "machine vision",
    "turing machine",
    "unsupervised learning",
    "a\.i\.",
    "semi-supervised learning",
    "reinforcement learning",
    "computational intelligence",
    "automata",
    "evolutionary computation",
    "bayesian networks"
]
obj = regex_search.KeyWordListSearchAgent(queries, courses_df=uvm_df)

# %%
test_df = obj.full_df

# %%
from sklearn.metrics import confusion_matrix
confused = confusion_matrix(test_df['has_ai'], test_df['any_keyword_present'])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Create the display object
disp = ConfusionMatrixDisplay(confusion_matrix=confused)

# Plot the matrix
disp.plot(cmap='Blues')
plt.title('Confusion matrix for regex approach')
plt.show()
