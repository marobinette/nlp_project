# %%
import pandas as pd
import sys
from pathlib import Path

# Add project root to path to enable imports
# If running from notebooks/ directory, go up one level to project root
sys.path.append('..')

from data.shared import CCData

# %%
data = pd.read_csv("../data/ipeds_231174.csv")

# Add IPEDS ID column from filename
data['ipeds'] = 231174

# Map IPEDS ID to university name using the CCData class
data['university'] = data['ipeds'].map(CCData.UNIVERSITY_DICTIONARY)

data.head()
# Out:
#                                 id           catalog_id  \
# 0  231174_ug_2005_2006_753_0_surya  231174_ug_2005_2006
# 1   231174_ug_2014_2015_20_0_surya  231174_ug_2014_2015
# 2  231174_ug_2014_2015_106_1_surya  231174_ug_2014_2015
# 3   231174_ug_2014_2015_89_0_surya  231174_ug_2014_2015
# 4   231174_ug_2014_2015_34_0_surya  231174_ug_2014_2015
#
#                             png_id           script   tool  \
# 0  231174_ug_2005_2006_753_0_split  migration.ipynb  surya
# 1   231174_ug_2014_2015_20_0_split      ocrsplitpng  surya
# 2  231174_ug_2014_2015_106_1_split      ocrsplitpng  surya
# 3   231174_ug_2014_2015_89_0_split      ocrsplitpng  surya
# 4   231174_ug_2014_2015_34_0_split  migration.ipynb  surya
#
#                                                 path  misc  \
# 0  /mnt/compethicslab/cc/data/231174/texts/surya/...   NaN
# 1  /mnt/compethicslab/cc/data/231174/texts/surya/...   NaN
# 2  /mnt/compethicslab/cc/data/231174/texts/surya/...   NaN
# ...
